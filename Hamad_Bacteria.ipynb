# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/Users/hamadwaheed/Desktop/KH_Round_1_Data - Round 1.csv')

# %%
df.head(130)
# Out:
#         Day        Date Sample Number % Cover  \
# 0    Monday  03/08/2021           GR1     20%
# 1    Monday  03/15/2021           GR1     25%
# 2    Monday  03/22/2021           GR1     30%
# 3    Monday  03/29/2021           GR1     40%
# 4    Monday  03/08/2021           GR2     25%
# ..      ...         ...           ...     ...
# 125  Monday  03/15/2021          LH24     NaN
# 126  Monday  03/22/2021          LH24     NaN
# 127  Monday  03/29/2021          LH24     40%
# 128  Monday  03/08/2021          LH25     NaN
# 129  Monday  03/15/2021          LH25     NaN
#
#     # of Bacterial Species Suspected (white or pink) Notes:  (Contaminated?)  \
# 0                                                  2            contaminated
# 1                                                  2            contaminated
# 2                                                  2            contaminated
# 3                                                  2            contaminated
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 14 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Day                                               132 non-null    object
#  1   Date                                              132 non-null    object
#  2   Sample Number                                     132 non-null    object
#  3   % Cover                                           109 non-null    object
#  4   # of Bacterial Species Suspected (white or pink)  109 non-null    object
#  5   Notes:  (Contaminated?)                           109 non-null    object
#  6   Unnamed: 6                                        0 non-null      float64
#  7   Unnamed: 7                                        0 non-null      float64
#  8   Week #                                            4 non-null      object
# ...

# %%
y = df['% Cover'].value_counts()
sns.barplot(y.index, y.values)

# %%
del df['Unnamed: 6']

# %%
del df['Unnamed: 7']

# %%
del df['Unnamed: 11']

# %%
df['% Cover'] = df['% Cover'].str.replace('%', '')
df['% Cover']
# Out:
# 0       20
# 1       25
# 2       30
# 3       40
# 4       25
#       ...
# 127     40
# 128    NaN
# 129    NaN
# 130    NaN
# 131     35
# Name: % Cover, Length: 132, dtype: object

# %%
pd.to_numeric(df['% Cover'])
# Out:
# 0      20.0
# 1      25.0
# 2      30.0
# 3      40.0
# 4      25.0
#        ...
# 127    40.0
# 128     NaN
# 129     NaN
# 130     NaN
# 131    35.0
# Name: % Cover, Length: 132, dtype: float64

# %%
df['% Cover']
# Out:
# 0       20
# 1       25
# 2       30
# 3       40
# 4       25
#       ...
# 127     40
# 128    NaN
# 129    NaN
# 130    NaN
# 131     35
# Name: % Cover, Length: 132, dtype: object

# %%
df['% Cover'] = pd.to_numeric(df['% Cover'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 11 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Day                                               132 non-null    object
#  1   Date                                              132 non-null    object
#  2   Sample Number                                     132 non-null    object
#  3   % Cover                                           109 non-null    float64
#  4   # of Bacterial Species Suspected (white or pink)  109 non-null    object
#  5   Notes:  (Contaminated?)                           109 non-null    object
#  6   Week #                                            4 non-null      object
#  7   Dates                                             4 non-null      object
#  8   Plant Species plated                              4 non-null      object
# ...

# %% [markdown]
# ## Converting dates to week number

# %%
df['Date'] = df['Date'].str.replace('03/08/2021', 'Week 1')

# %%
df['Date'] = df['Date'].str.replace('03/15/2021', 'Week 2')

# %%
df['Date'] = df['Date'].str.replace('03/22/2021', 'Week 3')

# %%
df['Date'] = df['Date'].str.replace('03/29/2021', 'Week 4')

# %%
df.head()
# Out:
#       Day    Date Sample Number  % Cover  \
# 0  Monday  Week 1           GR1     20.0
# 1  Monday  Week 2           GR1     25.0
# 2  Monday  Week 3           GR1     30.0
# 3  Monday  Week 4           GR1     40.0
# 4  Monday  Week 1           GR2     25.0
#
#   # of Bacterial Species Suspected (white or pink) Notes:  (Contaminated?)  \
# 0                                                2            contaminated
# 1                                                2            contaminated
# 2                                                2            contaminated
# 3                                                2            contaminated
# 4                                                1        not contaminated
#
#      Week #              Dates Plant Species plated Plant Species  \
# 0  Week 1:    March 8-March 12               GR1-25            GR
# 1  Week 2:   March 15-March 19      GR1-25 + LH1-22           LH
# ...

# %% [markdown]
# ## Converting GR# to GR

# %%
df.head()
# Out:
#       Day    Date Sample Number  % Cover  \
# 0  Monday  Week 1           GR1     20.0
# 1  Monday  Week 2           GR1     25.0
# 2  Monday  Week 3           GR1     30.0
# 3  Monday  Week 4           GR1     40.0
# 4  Monday  Week 1           GR2     25.0
#
#   # of Bacterial Species Suspected (white or pink) Notes:  (Contaminated?)  \
# 0                                                2            contaminated
# 1                                                2            contaminated
# 2                                                2            contaminated
# 3                                                2            contaminated
# 4                                                1        not contaminated
#
#      Week #              Dates Plant Species plated Plant Species  \
# 0  Week 1:    March 8-March 12               GR1-25            GR
# 1  Week 2:   March 15-March 19      GR1-25 + LH1-22           LH
# ...

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR1', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR2', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR3', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR4', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR7', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR8', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR9', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR10', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR11', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR13', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR15', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR18', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR20', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR21', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR23', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR24', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR25', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR0', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR1', 'GR')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('GR5', 'GR')

# %%
df.head(20)
# Out:
#        Day    Date Sample Number  % Cover  \
# 0   Monday  Week 1            GR     20.0
# 1   Monday  Week 2            GR     25.0
# 2   Monday  Week 3            GR     30.0
# 3   Monday  Week 4            GR     40.0
# 4   Monday  Week 1            GR     25.0
# 5   Monday  Week 2            GR     35.0
# 6   Monday  Week 3            GR     45.0
# 7   Monday  Week 4            GR     50.0
# 8   Monday  Week 1            GR     15.0
# 9   Monday  Week 2            GR     25.0
# 10  Monday  Week 3            GR     30.0
# 11  Monday  Week 4            GR     35.0
# 12  Monday  Week 1            GR     20.0
# 13  Monday  Week 2            GR     30.0
# 14  Monday  Week 3            GR     35.0
# 15  Monday  Week 4            GR     40.0
# 16  Monday  Week 1            GR     25.0
# 17  Monday  Week 2            GR     30.0
# 18  Monday  Week 3            GR     35.0
# 19  Monday  Week 4            GR     40.0
#
# ...

# %% [markdown]
# ## Converting LH# to LH

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH1', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH4', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH6', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH8', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH9', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH10', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH11', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH12', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH15', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH16', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH18', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH19', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH20', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH23', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH24', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH25', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH0', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH2', 'LH')

# %%
df['Sample Number'] = df['Sample Number'].str.replace('LH5', 'LH')

# %%
df.head(150)
# Out:
#         Day    Date Sample Number  % Cover  \
# 0    Monday  Week 1            GR     20.0
# 1    Monday  Week 2            GR     25.0
# 2    Monday  Week 3            GR     30.0
# 3    Monday  Week 4            GR     40.0
# 4    Monday  Week 1            GR     25.0
# 5    Monday  Week 2            GR     35.0
# 6    Monday  Week 3            GR     45.0
# 7    Monday  Week 4            GR     50.0
# 8    Monday  Week 1            GR     15.0
# 9    Monday  Week 2            GR     25.0
# 10   Monday  Week 3            GR     30.0
# 11   Monday  Week 4            GR     35.0
# 12   Monday  Week 1            GR     20.0
# 13   Monday  Week 2            GR     30.0
# 14   Monday  Week 3            GR     35.0
# 15   Monday  Week 4            GR     40.0
# 16   Monday  Week 1            GR     25.0
# 17   Monday  Week 2            GR     30.0
# 18   Monday  Week 3            GR     35.0
# 19   Monday  Week 4            GR     40.0
# 20   Monday  Week 1            GR     15.0
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
 ax = sns.boxplot(x="Date", y="% Cover", hue="Sample Number",
...                  data=df, palette="Set3")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 11 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Day                                               132 non-null    object
#  1   Date                                              132 non-null    object
#  2   Sample Number                                     132 non-null    object
#  3   % Cover                                           109 non-null    float64
#  4   # of Bacterial Species Suspected (white or pink)  109 non-null    object
#  5   Notes:  (Contaminated?)                           109 non-null    object
#  6   Week #                                            4 non-null      object
#  7   Dates                                             4 non-null      object
#  8   Plant Species plated                              4 non-null      object
# ...

# %%
df.head()
# Out:
#       Day    Date Sample Number  % Cover  \
# 0  Monday  Week 1            GR     20.0
# 1  Monday  Week 2            GR     25.0
# 2  Monday  Week 3            GR     30.0
# 3  Monday  Week 4            GR     40.0
# 4  Monday  Week 1            GR     25.0
#
#   # of Bacterial Species Suspected (white or pink) Notes:  (Contaminated?)  \
# 0                                                2            contaminated
# 1                                                2            contaminated
# 2                                                2            contaminated
# 3                                                2            contaminated
# 4                                                1        not contaminated
#
#      Week #              Dates Plant Species plated Plant Species  \
# 0  Week 1:    March 8-March 12               GR1-25            GR
# 1  Week 2:   March 15-March 19      GR1-25 + LH1-22           LH
# ...

# %%
df.to_csv(r'/Users/hamadwaheed/Desktop\Bacteria_Data.csv', index = False)
